# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Que1. Read the dataset to the python environment.

# %%
data = pd.read_csv('cars_data.csv')

# %%
data
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # Que2. Check for the null values present in the dataset.

# %%
data.isnull()
# Out:
#        Make  Model  Nickname  Car Gender  Buyer Gender  Buyer Age  Buzzword  \
# 0     False  False     False       False         False      False     False
# 1     False  False     False       False         False      False     False
# 2     False  False     False       False         False      False     False
# 3     False  False     False       False         False      False     False
# 4     False  False     False       False         False      False     False
# ...     ...    ...       ...         ...           ...        ...       ...
# 9995  False  False     False       False         False      False     False
# 9996  False  False     False       False         False      False     False
# 9997  False  False     False       False         False      False     False
# 9998  False  False     False       False         False      False     False
# 9999  False  False     False       False         False      False     False
#
# ...

# %%
data.isnull().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # Que3. Plot a bar graph of male vs female buyers participated in the sales.

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='Buyer Gender',data=data,)
plt.title('Male vs Female',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Male vs Female')

# %% [markdown]
# # Que4. Find the top 5 cars based on their sales price.

# %%
data['Sale Price'].nlargest(n=5)
# Out:
# 5984    99997.65
# 1270    99991.91
# 3460    99983.38
# 9032    99978.17
# 302     99973.44
# Name: Sale Price, dtype: float64

# %% [markdown]
# # Que5. Find the least 5 cars based on their Resell price.

# %%
data['Resell Price'].nsmallest(n=5)
# Out:
# 2446    2000.84
# 4933    2005.44
# 566     2014.09
# 2538    2017.24
# 5869    2017.83
# Name: Resell Price, dtype: float64
